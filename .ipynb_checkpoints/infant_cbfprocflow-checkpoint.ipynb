# %%
import os
from os.path import join as opj
from nipype.interfaces.utility import Function, IdentityInterface, Merge
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.interfaces.slicer.registration import brainsresample
from nipype.algorithms.misc import Gunzip
from nipype.pipeline.engine import Workflow, Node, MapNode
from nipype.interfaces.freesurfer.preprocess import MRIConvert, ApplyVolTransform
from nipype.interfaces.fsl.utils import Reorient2Std
from nipype.interfaces.fsl.maths import ApplyMask
from nipype.interfaces.fsl.preprocess import FLIRT
from nipype.interfaces.freesurfer.model import Binarize

# MATLAB setup - Specify path to current SPM and the MATLAB's default mode
from nipype.interfaces.matlab import MatlabCommand
MatlabCommand.set_default_paths('~/spm12/toolbox')
MatlabCommand.set_default_matlab_cmd("matlab -nodesktop -nosplash")

#other study-specific variables
project_home = '/Volumes/iang/active/BABIES/BABIES_perfusion'
raw_dir = project_home + '/Raw'
subjects_list = open(project_home + '/Misc/Subjects.txt').read().splitlines()
#subjects_list = ['012']
output_dir = project_home + '/Proc'
wkflow_dir = project_home + '/Workflows'
template = project_home + '/Templates/T2wtemplate_2mm.nii'

#Population specific variables for ASL
nex_asl = 3 #number of excitations from the 3D ASL scan parameters
inversion_efficiency = 0.8 #from GE
background_supp_eff = 0.75 #from GE
efficiency = inversion_efficiency * background_supp_eff 
T1_blood = 1.6 #T1 of blood in seconds(1.6s at 3T and 1.4s at 1.5T)
sat_time = 2 #in seconds, from GE
partition_coeff = 0.9 #whole brain average in ml/g
scaling_factor = 32 #scaling factor, can be taken from PW dicom header at position 0043,107f (corresponds to #coils?)
postlabel_delay = 1.525 #post label delay in seconds
labeling_time = 1.450 #labeling time in seconds
T1_tissue = 1.2 #estimated T1 of grey matter in seconds
TR = 4.844 #repetition time

# FSL set up- change default file output type
from nipype.interfaces.fsl import FSLCommand
FSLCommand.set_default_output_type('NIFTI')

# %%
## File handling nodes

# Select subjects
infosource = Node(IdentityInterface(fields=['subjid', 'volume']),
                  name='infosource')
infosource.iterables = [('subjid', subjects_list)]


# SelectFiles
templates = {'pw_volume': raw_dir + '/{subjid}-C-T1/pw.nii',
             'anat_volume': raw_dir + '/{subjid}-C-T1/processed_t2.nii',
             'pd_volume': raw_dir + '/{subjid}-C-T1/pd.nii'}
selectfiles = Node(SelectFiles(templates), name='selectfiles')


# Datasink
datasink = Node(DataSink(), name='datasink')
datasink.inputs.base_directory = output_dir
datasink.inputs.container = output_dir
# DataSink output substitutions (for ease of folder naming)
substitutions = [('_subjid_', ''),
                ('volume_',''),
                ('_reoriented',''),
                ('_warped','')]
datasink.inputs.substitutions = substitutions

# %%
## File Processing nodes

# convert files to nifti
mri_convert = Node(MRIConvert(out_type='nii',
                                conform_size=2,
                                crop_size= (128, 128, 128)), 
                   name='mri_convert')

# reorient data for consistency
reorient_anat = Node(Reorient2Std(output_type='NIFTI'),
                     name='reorient_anat')

# reorient data for consistency
reorient_pd = Node(Reorient2Std(output_type='NIFTI'),
                   name='reorient_pd')

# reorient data for consistency
reorient_pw = Node(Reorient2Std(output_type='NIFTI'),
                   name='reorient_pw')


# Binarize -  binarize and dilate image to create a brainmask
binarize = Node(Binarize(min=0.5,
                         dilate=2,
                         erode=1,
                         out_type='nii'),
                name='binarize')

    

reg2anat = Node(FLIRT(out_matrix_file = 'xform.mat'), name = 'reg2anat')
applyxform = Node(FLIRT(apply_xfm = True), name = 'applyxform')

# Mask brain in pw and pd volumes
applyMask_pd = Node(ApplyMask(output_type='NIFTI'), 
                    name='applyMask_pd')

applyMask_pw = Node(ApplyMask(output_type='NIFTI'), 
                    name='applyMask_pw')

# N3 bias correction using MINC tools, will be necessary for babies
# nu_correct = Node(fs.MNIBiasCorrection(), name='nu_correct')

# %%
# Data QC nodes
def create_coreg_plot(epi,anat):
    import os
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nilearn import plotting
    
    coreg_filename='coregistration.png'
    display = plotting.plot_anat(epi, display_mode='ortho',
                                 draw_cross=False,
                                 title = 'coregistration to anatomy')
    display.add_edges(anat)
    display.savefig(coreg_filename) 
    display.close()
    coreg_file = os.path.abspath(coreg_filename)
    
    return(coreg_file)

def check_mask_coverage(epi,brainmask):
    import os
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nilearn import plotting
    
    maskcheck_filename='maskcheck.png'
    display = plotting.plot_anat(epi, display_mode='ortho',
                                 draw_cross=False,
                                 title = 'brainmask coverage')
    display.add_contours(brainmask,levels=[.5], colors='r')
    display.savefig(maskcheck_filename)
    display.close()
    maskcheck_file = os.path.abspath(maskcheck_filename)

    return(maskcheck_file)

make_coreg_img = Node(name='make_coreg_img',
                      interface=Function(input_names=['epi','anat'],
                                         output_names=['coreg_file'],
                                         function=create_coreg_plot))

make_checkmask_img = Node(name='make_checkmask_img',
                      interface=Function(input_names=['epi','brainmask'],
                                         output_names=['maskcheck_file'],
                                         function=check_mask_coverage))

# %%
# Create a flow for preprocessing anat + asl volumes 
preprocflow = Workflow(name='preprocflow')

# Connect all components of the preprocessing workflow
preprocflow.connect([(infosource, selectfiles, [('subjid', 'subjid')]),
                     (selectfiles, mri_convert, [('anat_volume', 'in_file')]),
                     (mri_convert, reorient_anat, [('out_file', 'in_file')]),    
                     (selectfiles, reorient_pw, [('pw_volume', 'in_file')]), 
                     (selectfiles, reorient_pd, [('pd_volume', 'in_file')]),
                     (reorient_anat, reg2anat, [('out_file', 'reference')]),
                     (reorient_pw, reg2anat, [('out_file', 'in_file')]),
                     (reg2anat, applyxform, [('out_matrix_file','in_matrix_file')]),
                     (reorient_anat, applyxform, [('out_file','reference')]),
                     (reorient_pd, applyxform, [('out_file','in_file')]),
                     (reorient_anat, binarize, [('out_file','in_file')]),
                     (applyxform, applyMask_pd, [('out_file','in_file')]),
                     (binarize, applyMask_pd, [('binary_file','mask_file')]),
                     (reg2anat, applyMask_pw, [('out_file','in_file')]),
                     (binarize, applyMask_pw, [('binary_file','mask_file')]),
                     (reg2anat, make_coreg_img, [('out_file','epi')]),
                     (reorient_anat, make_coreg_img, [('out_file','anat')]),
                     (make_coreg_img, datasink, [('coreg_file','coreg_check')]),
                     (reg2anat, make_checkmask_img, [('out_file','epi')]),
                     (binarize, make_checkmask_img, [('binary_file','brainmask')]),
                     (make_checkmask_img, datasink, [('maskcheck_file','masked_check')]),
                     (applyMask_pd, datasink, [('out_file','masked_pd')]),
                     (applyMask_pw, datasink, [('out_file','masked_pw')]),
                     (reorient_anat, datasink, [('out_file', 'reorient_anat')])
                    ])
preprocflow.base_dir = opj(wkflow_dir)
preprocflow.write_graph(graph2use='flat')
preprocflow.run('MultiProc', plugin_args={'n_procs': 2})
# Out:
# 170823-15:45:56,54 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/graph.dot.png (graph2use=flat, simple_form=True).
# 170823-15:45:56,97 workflow INFO:
# 	 Workflow preprocflow settings: ['check', 'execution', 'logging']
# 170823-15:45:56,356 workflow INFO:
# 	 Running in parallel.
# 170823-15:45:56,371 workflow INFO:
# 	 Executing: selectfiles.a12 ID: 0
# 170823-15:45:56,378 workflow INFO:
# 	 Executing: selectfiles.a11 ID: 13
# 170823-15:45:56,383 workflow INFO:
# 	 Executing node selectfiles.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/selectfiles
# 170823-15:45:56,388 workflow INFO:
# 	 Executing node selectfiles.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/selectfiles
# 170823-15:45:56,549 workflow INFO:
# 	 [Job finished] jobname: selectfiles.a12 jobid: 0
# 170823-15:45:56,558 workflow INFO:
# 	 Executing: mri_convert.a12 ID: 1
# 170823-15:45:56,571 workflow INFO:
# 	 [Job finished] jobname: selectfiles.a11 jobid: 13
# 170823-15:45:56,574 workflow INFO:
# 	 Executing node mri_convert.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/mri_convert
# 170823-15:45:56,580 workflow INFO:
# 	 Executing: reorient_pw.a12 ID: 4
# 170823-15:45:56,593 workflow INFO:
# 	 Executing node reorient_pw.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_pw
# 170823-15:45:56,662 workflow INFO:
# 	 Running: mri_convert --conform_size 2.0 --cropsize 128 128 128 --out_type nii --input_volume /Volumes/iang/active/BABIES/BABIES_perfusion/Raw/033x-C-T1/processed_t2.nii --output_volume /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/mri_convert/processed_t2_out.nii
# 170823-15:45:56,676 workflow INFO:
# 	 Running: fslreorient2std /Volumes/iang/active/BABIES/BABIES_perfusion/Raw/033x-C-T1/pw.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_pw/pw_reoriented.nii
# 170823-15:45:58,193 workflow INFO:
# 	 [Job finished] jobname: reorient_pw.a12 jobid: 4
# 170823-15:45:58,199 workflow INFO:
# 	 Executing: reorient_pd.a12 ID: 9
# 170823-15:45:58,212 workflow INFO:
# 	 Executing node reorient_pd.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_pd
# 170823-15:45:58,303 workflow INFO:
# 	 Running: fslreorient2std /Volumes/iang/active/BABIES/BABIES_perfusion/Raw/033x-C-T1/pd.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_pd/pd_reoriented.nii
# 170823-15:45:59,120 workflow INFO:
# 	 [Job finished] jobname: reorient_pd.a12 jobid: 9
# 170823-15:45:59,129 workflow INFO:
# 	 Executing: mri_convert.a11 ID: 14
# 170823-15:45:59,144 workflow INFO:
# 	 Executing node mri_convert.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/mri_convert
# 170823-15:45:59,239 workflow INFO:
# 	 Running: mri_convert --conform_size 2.0 --cropsize 128 128 128 --out_type nii --input_volume /Volumes/iang/active/BABIES/BABIES_perfusion/Raw/002x-C-T1/processed_t2.nii --output_volume /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/mri_convert/processed_t2_out.nii
# 170823-15:46:05,16 workflow INFO:
# 	 [Job finished] jobname: mri_convert.a12 jobid: 1
# 170823-15:46:05,20 workflow INFO:
# 	 Executing: reorient_anat.a12 ID: 2
# 170823-15:46:05,42 workflow INFO:
# 	 Executing node reorient_anat.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_anat
# 170823-15:46:05,125 workflow INFO:
# 	 Running: fslreorient2std /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/mri_convert/processed_t2_out.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_anat/processed_t2_out_reoriented.nii
# 170823-15:46:05,860 workflow INFO:
# 	 [Job finished] jobname: reorient_anat.a12 jobid: 2
# 170823-15:46:05,867 workflow INFO:
# 	 Executing: binarize.a12 ID: 3
# 170823-15:46:05,888 workflow INFO:
# 	 Executing node binarize.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/binarize
# 170823-15:46:05,983 workflow INFO:
# 	 Running: mri_binarize --o /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/binarize/processed_t2_out_reoriented_thresh.nii --dilate 2 --erode  1 --i /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/binarize/processed_t2_out_reoriented.nii --min 0.500000
# 170823-15:46:07,464 workflow INFO:
# 	 [Job finished] jobname: mri_convert.a11 jobid: 14
# 170823-15:46:07,473 workflow INFO:
# 	 Executing: reg2anat.a12 ID: 5
# 170823-15:46:07,492 workflow INFO:
# 	 Executing node reg2anat.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reg2anat
# 170823-15:46:07,577 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_pw/pw_reoriented.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_anat/processed_t2_out_reoriented.nii -out pw_reoriented_flirt.nii -omat xform.mat
# 170823-15:46:07,999 workflow INFO:
# 	 [Job finished] jobname: binarize.a12 jobid: 3
# 170823-15:46:08,5 workflow INFO:
# 	 Executing: reorient_anat.a11 ID: 15
# 170823-15:46:08,51 workflow INFO:
# 	 Executing node reorient_anat.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_anat
# 170823-15:46:08,148 workflow INFO:
# 	 Running: fslreorient2std /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/mri_convert/processed_t2_out.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_anat/processed_t2_out_reoriented.nii
# 170823-15:46:08,892 workflow INFO:
# 	 [Job finished] jobname: reorient_anat.a11 jobid: 15
# 170823-15:46:08,899 workflow INFO:
# 	 Executing: binarize.a11 ID: 16
# 170823-15:46:08,917 workflow INFO:
# 	 Executing node binarize.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/binarize
# 170823-15:46:09,14 workflow INFO:
# 	 Running: mri_binarize --o /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/binarize/processed_t2_out_reoriented_thresh.nii --dilate 2 --erode  1 --i /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/binarize/processed_t2_out_reoriented.nii --min 0.500000
# 170823-15:46:10,944 workflow INFO:
# 	 [Job finished] jobname: binarize.a11 jobid: 16
# 170823-15:46:10,950 workflow INFO:
# 	 Executing: reorient_pw.a11 ID: 17
# 170823-15:46:10,964 workflow INFO:
# 	 Executing node reorient_pw.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pw
# 170823-15:46:11,48 workflow INFO:
# 	 Running: fslreorient2std /Volumes/iang/active/BABIES/BABIES_perfusion/Raw/002x-C-T1/pw.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pw/pw_reoriented.nii
# 170823-15:46:12,8 workflow INFO:
# 	 [Job finished] jobname: reorient_pw.a11 jobid: 17
# 170823-15:46:12,17 workflow INFO:
# 	 Executing: reg2anat.a11 ID: 18
# 170823-15:46:12,39 workflow INFO:
# 	 Executing node reg2anat.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reg2anat
# 170823-15:46:12,132 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pw/pw_reoriented.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_anat/processed_t2_out_reoriented.nii -out pw_reoriented_flirt.nii -omat xform.mat
# 170823-15:46:39,627 workflow INFO:
# 	 [Job finished] jobname: reg2anat.a12 jobid: 5
# 170823-15:46:39,633 workflow INFO:
# 	 Executing: applyMask_pw.a12 ID: 6
# 170823-15:46:39,689 workflow INFO:
# 	 Executing node applyMask_pw.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pw
# 170823-15:46:39,771 workflow INFO:
# 	 Running: fslmaths /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reg2anat/pw_reoriented_flirt.nii -mas /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/binarize/processed_t2_out_reoriented_thresh.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pw/pw_reoriented_flirt_masked.nii
# 170823-15:46:40,680 workflow INFO:
# 	 [Job finished] jobname: applyMask_pw.a12 jobid: 6
# 170823-15:46:40,686 workflow INFO:
# 	 Executing: make_coreg_img.a12 ID: 7
# 170823-15:46:40,721 workflow INFO:
# 	 Executing node make_coreg_img.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_coreg_img
# 170823-15:46:42,435 workflow DEBUG:
# 	 Needed files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_coreg_img/coregistration.png;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_coreg_img/_0xb945863e1000eccdbedb3f07789eb68a_unfinished.json;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_coreg_img/_inputs.pklz;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_coreg_img/_node.pklz
# 170823-15:46:42,440 workflow DEBUG:
# 	 Needed dirs: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_coreg_img/_report
# 170823-15:46:42,455 workflow DEBUG:
# 	 Removing files:
# 170823-15:46:42,469 workflow DEBUG:
# 	 saved results in /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_coreg_img/result_make_coreg_img.pklz
# 170823-15:46:42,485 workflow DEBUG:
# 	 writing post-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_coreg_img/_report/report.rst
# 170823-15:46:42,499 workflow DEBUG:
# 	 Finished running make_coreg_img.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_coreg_img
#
# 170823-15:46:42,503 workflow INFO:
# 	 [Job finished] jobname: make_coreg_img.a12 jobid: 7
# 170823-15:46:42,511 workflow INFO:
# 	 Executing: make_checkmask_img.a12 ID: 8
# 170823-15:46:42,531 workflow INFO:
# 	 Executing node make_checkmask_img.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_checkmask_img
# 170823-15:46:42,540 workflow DEBUG:
# 	 Found hashfiles: []
# 170823-15:46:42,547 workflow DEBUG:
# 	 Final hashfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_checkmask_img/_0x0caa4fe266dccfd5838db3d12805ebab.json
# 170823-15:46:42,553 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 170823-15:46:42,557 workflow DEBUG:
# 	 Node hash: 0caa4fe266dccfd5838db3d12805ebab
# 170823-15:46:42,565 workflow DEBUG:
# 	 /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_checkmask_img/_0x0caa4fe266dccfd5838db3d12805ebab_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 170823-15:46:42,571 workflow DEBUG:
# 	 Creating /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_checkmask_img
# 170823-15:46:42,600 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_checkmask_img/_report/report.rst
# 170823-15:46:42,655 workflow DEBUG:
# 	 Executing node
# 170823-15:46:42,658 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 170823-15:46:43,924 workflow DEBUG:
# 	 Needed files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_checkmask_img/maskcheck.png;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_checkmask_img/_0x0caa4fe266dccfd5838db3d12805ebab_unfinished.json;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_checkmask_img/_inputs.pklz;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_checkmask_img/_node.pklz
# 170823-15:46:43,927 workflow DEBUG:
# 	 Needed dirs: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_checkmask_img/_report
# 170823-15:46:43,941 workflow DEBUG:
# 	 Removing files:
# 170823-15:46:43,959 workflow DEBUG:
# 	 saved results in /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_checkmask_img/result_make_checkmask_img.pklz
# 170823-15:46:43,972 workflow DEBUG:
# 	 writing post-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_checkmask_img/_report/report.rst
# 170823-15:46:43,986 workflow DEBUG:
# 	 Finished running make_checkmask_img.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_checkmask_img
#
# 170823-15:46:43,990 workflow INFO:
# 	 [Job finished] jobname: make_checkmask_img.a12 jobid: 8
# 170823-15:46:43,996 workflow INFO:
# 	 Executing: applyxform.a12 ID: 10
# 170823-15:46:44,19 workflow INFO:
# 	 Executing node applyxform.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform
# 170823-15:46:44,26 workflow DEBUG:
# 	 Found hashfiles: []
# 170823-15:46:44,29 workflow DEBUG:
# 	 Final hashfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform/_0x99b0723f215c1e9b33ec776eccc50a4c.json
# 170823-15:46:44,33 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 170823-15:46:44,42 workflow DEBUG:
# 	 Node hash: 99b0723f215c1e9b33ec776eccc50a4c
# 170823-15:46:44,48 workflow DEBUG:
# 	 /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform/_0x99b0723f215c1e9b33ec776eccc50a4c_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 170823-15:46:44,51 workflow DEBUG:
# 	 Creating /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform
# 170823-15:46:44,70 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform/_report/report.rst
# 170823-15:46:44,124 workflow DEBUG:
# 	 Executing node
# 170823-15:46:44,127 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 170823-15:46:44,133 interface DEBUG:
# 	 apply_xfm_True
# 170823-15:46:44,142 interface DEBUG:
# 	 in_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_pd/pd_reoriented.nii
# 170823-15:46:44,148 interface DEBUG:
# 	 in_matrix_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reg2anat/xform.mat
# 170823-15:46:44,151 interface DEBUG:
# 	 out_file_pd_reoriented_flirt.nii
# 170823-15:46:44,154 interface DEBUG:
# 	 out_matrix_file_pd_reoriented_flirt.mat
# 170823-15:46:44,158 interface DEBUG:
# 	 reference_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_anat/processed_t2_out_reoriented.nii
# 170823-15:46:44,175 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_pd/pd_reoriented.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_anat/processed_t2_out_reoriented.nii -out pd_reoriented_flirt.nii -omat pd_reoriented_flirt.mat -applyxfm -init /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reg2anat/xform.mat
# 170823-15:46:44,185 interface DEBUG:
# 	 apply_xfm_True
# 170823-15:46:44,188 interface DEBUG:
# 	 in_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_pd/pd_reoriented.nii
# 170823-15:46:44,192 interface DEBUG:
# 	 in_matrix_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reg2anat/xform.mat
# 170823-15:46:44,195 interface DEBUG:
# 	 out_file_pd_reoriented_flirt.nii
# 170823-15:46:44,198 interface DEBUG:
# 	 out_matrix_file_pd_reoriented_flirt.mat
# 170823-15:46:44,202 interface DEBUG:
# 	 reference_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_anat/processed_t2_out_reoriented.nii
# 170823-15:46:44,207 interface DEBUG:
# 	 {'DISPLAY': ':1'}
# 170823-15:46:44,894 workflow DEBUG:
# 	 Needed files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform/pd_reoriented_flirt.nii;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform/pd_reoriented_flirt.mat;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform/_0x99b0723f215c1e9b33ec776eccc50a4c_unfinished.json;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform/command.txt;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform/_inputs.pklz;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform/_node.pklz
# 170823-15:46:44,901 workflow DEBUG:
# 	 Needed dirs: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform/_report
# 170823-15:46:44,920 workflow DEBUG:
# 	 Removing files:
# 170823-15:46:44,933 workflow DEBUG:
# 	 saved results in /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform/result_applyxform.pklz
# 170823-15:46:44,946 workflow DEBUG:
# 	 writing post-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform/_report/report.rst
# 170823-15:46:44,960 workflow DEBUG:
# 	 Finished running applyxform.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform
#
# 170823-15:46:44,967 workflow INFO:
# 	 [Job finished] jobname: applyxform.a12 jobid: 10
# 170823-15:46:44,974 workflow INFO:
# 	 Executing: applyMask_pd.a12 ID: 11
# 170823-15:46:44,994 workflow INFO:
# 	 Executing node applyMask_pd.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd
# 170823-15:46:45,4 workflow DEBUG:
# 	 Found hashfiles: []
# 170823-15:46:45,7 workflow DEBUG:
# 	 Final hashfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/_0x217a153c0e4f075ab3ca65f52bdc9f58.json
# 170823-15:46:45,11 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 170823-15:46:45,15 workflow DEBUG:
# 	 Node hash: 217a153c0e4f075ab3ca65f52bdc9f58
# 170823-15:46:45,20 workflow DEBUG:
# 	 /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/_0x217a153c0e4f075ab3ca65f52bdc9f58_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 170823-15:46:45,26 workflow DEBUG:
# 	 Creating /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd
# 170823-15:46:45,69 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/_report/report.rst
# 170823-15:46:45,115 workflow DEBUG:
# 	 Executing node
# 170823-15:46:45,124 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 170823-15:46:45,131 interface DEBUG:
# 	 in_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform/pd_reoriented_flirt.nii
# 170823-15:46:45,134 interface DEBUG:
# 	 mask_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/binarize/processed_t2_out_reoriented_thresh.nii
# 170823-15:46:45,138 interface DEBUG:
# 	 out_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/pd_reoriented_flirt_masked.nii
# 170823-15:46:45,152 workflow INFO:
# 	 Running: fslmaths /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform/pd_reoriented_flirt.nii -mas /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/binarize/processed_t2_out_reoriented_thresh.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/pd_reoriented_flirt_masked.nii
# 170823-15:46:45,159 interface DEBUG:
# 	 in_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyxform/pd_reoriented_flirt.nii
# 170823-15:46:45,166 interface DEBUG:
# 	 mask_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/binarize/processed_t2_out_reoriented_thresh.nii
# 170823-15:46:45,171 interface DEBUG:
# 	 out_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/pd_reoriented_flirt_masked.nii
# 170823-15:46:45,177 interface DEBUG:
# 	 {'DISPLAY': ':1'}
# 170823-15:46:45,811 workflow DEBUG:
# 	 Needed files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/pd_reoriented_flirt_masked.nii;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/pd_reoriented_flirt_masked.mat;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/_0x217a153c0e4f075ab3ca65f52bdc9f58_unfinished.json;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/command.txt;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/_inputs.pklz;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/_node.pklz
# 170823-15:46:45,815 workflow DEBUG:
# 	 Needed dirs: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/_report
# 170823-15:46:45,831 workflow DEBUG:
# 	 Removing files:
# 170823-15:46:45,844 workflow DEBUG:
# 	 saved results in /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/result_applyMask_pd.pklz
# 170823-15:46:45,860 workflow DEBUG:
# 	 writing post-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/_report/report.rst
# 170823-15:46:45,876 workflow DEBUG:
# 	 Finished running applyMask_pd.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd
#
# 170823-15:46:45,881 workflow INFO:
# 	 [Job finished] jobname: applyMask_pd.a12 jobid: 11
# 170823-15:46:45,889 workflow INFO:
# 	 Executing: datasink.a12 ID: 12
# 170823-15:46:45,930 workflow INFO:
# 	 Executing node datasink.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/datasink
# 170823-15:46:45,940 workflow DEBUG:
# 	 Found hashfiles: []
# 170823-15:46:45,947 workflow DEBUG:
# 	 Final hashfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/datasink/_0x5b8ec996b4c8a0d014001f6449c636cb.json
# 170823-15:46:45,954 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=True, hash_exists=False
# 170823-15:46:45,958 workflow DEBUG:
# 	 Node hash: 5b8ec996b4c8a0d014001f6449c636cb
# 170823-15:46:45,963 workflow DEBUG:
# 	 /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/datasink/_0x5b8ec996b4c8a0d014001f6449c636cb_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 170823-15:46:45,972 workflow DEBUG:
# 	 Creating /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/datasink
# 170823-15:46:45,998 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/datasink/_report/report.rst
# 170823-15:46:46,57 workflow DEBUG:
# 	 Executing node
# 170823-15:46:46,61 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 170823-15:46:46,69 interface DEBUG:
# 	 key: reorient_anat files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_anat/processed_t2_out_reoriented.nii
# 170823-15:46:46,75 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/_subjid_033x/processed_t2_out_reoriented.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/033x/processed_t2_out_reoriented.nii using '_subjid_' -> ''
# 170823-15:46:46,78 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/033x/processed_t2_out_reoriented.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/033x/processed_t2_out.nii using '_reoriented' -> ''
# 170823-15:46:46,82 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/_subjid_033x/processed_t2_out_reoriented.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/033x/processed_t2_out.nii
# 170823-15:46:46,92 interface DEBUG:
# 	 copyfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/reorient_anat/processed_t2_out_reoriented.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/033x/processed_t2_out.nii
# 170823-15:46:46,190 interface DEBUG:
# 	 key: masked_pd files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/pd_reoriented_flirt_masked.nii
# 170823-15:46:46,193 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/_subjid_033x/pd_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/033x/pd_reoriented_flirt_masked.nii using '_subjid_' -> ''
# 170823-15:46:46,197 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/033x/pd_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/033x/pd_flirt_masked.nii using '_reoriented' -> ''
# 170823-15:46:46,202 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/_subjid_033x/pd_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/033x/pd_flirt_masked.nii
# 170823-15:46:46,212 interface DEBUG:
# 	 copyfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pd/pd_reoriented_flirt_masked.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/033x/pd_flirt_masked.nii
# 170823-15:46:46,552 interface DEBUG:
# 	 key: masked_pw files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pw/pw_reoriented_flirt_masked.nii
# 170823-15:46:46,555 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/_subjid_033x/pw_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/033x/pw_reoriented_flirt_masked.nii using '_subjid_' -> ''
# 170823-15:46:46,559 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/033x/pw_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/033x/pw_flirt_masked.nii using '_reoriented' -> ''
# 170823-15:46:46,563 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/_subjid_033x/pw_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/033x/pw_flirt_masked.nii
# 170823-15:46:46,579 interface DEBUG:
# 	 copyfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/applyMask_pw/pw_reoriented_flirt_masked.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/033x/pw_flirt_masked.nii
# 170823-15:46:47,40 interface DEBUG:
# 	 key: coreg_check files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_coreg_img/coregistration.png
# 170823-15:46:47,46 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/_subjid_033x/coregistration.png -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/033x/coregistration.png using '_subjid_' -> ''
# 170823-15:46:47,50 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/_subjid_033x/coregistration.png -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/033x/coregistration.png
# 170823-15:46:47,100 interface DEBUG:
# 	 copyfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_coreg_img/coregistration.png /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/033x/coregistration.png
# 170823-15:46:47,225 interface DEBUG:
# 	 key: masked_check files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_checkmask_img/maskcheck.png
# 170823-15:46:47,230 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/_subjid_033x/maskcheck.png -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/033x/maskcheck.png using '_subjid_' -> ''
# 170823-15:46:47,233 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/_subjid_033x/maskcheck.png -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/033x/maskcheck.png
# 170823-15:46:47,263 interface DEBUG:
# 	 copyfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/make_checkmask_img/maskcheck.png /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/033x/maskcheck.png
# 170823-15:46:47,404 workflow DEBUG:
# 	 Needed files: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/033x/processed_t2_out.nii;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/033x/processed_t2_out.mat;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/033x/pd_flirt_masked.nii;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/033x/pd_flirt_masked.mat;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/033x/pw_flirt_masked.nii;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/033x/pw_flirt_masked.mat;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/033x/coregistration.png;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/033x/maskcheck.png;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/datasink/_0x5b8ec996b4c8a0d014001f6449c636cb_unfinished.json;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/datasink/_inputs.pklz;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/datasink/_node.pklz
# 170823-15:46:47,411 workflow DEBUG:
# 	 Needed dirs: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/datasink/_report
# 170823-15:46:47,426 workflow DEBUG:
# 	 Removing files:
# 170823-15:46:47,439 workflow DEBUG:
# 	 saved results in /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/datasink/result_datasink.pklz
# 170823-15:46:47,456 workflow DEBUG:
# 	 writing post-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/datasink/_report/report.rst
# 170823-15:46:47,472 workflow DEBUG:
# 	 Finished running datasink.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_033x/datasink
#
# 170823-15:46:47,479 workflow INFO:
# 	 [Job finished] jobname: datasink.a12 jobid: 12
# 170823-15:46:47,485 workflow INFO:
# 	 Executing: reorient_pd.a11 ID: 22
# 170823-15:46:47,519 workflow INFO:
# 	 Executing node reorient_pd.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd
# 170823-15:46:47,525 workflow DEBUG:
# 	 Found hashfiles: []
# 170823-15:46:47,534 workflow DEBUG:
# 	 Final hashfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/_0x6c428c57c0d0091e7c15bc3a045652fb.json
# 170823-15:46:47,542 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 170823-15:46:47,546 workflow DEBUG:
# 	 Node hash: 6c428c57c0d0091e7c15bc3a045652fb
# 170823-15:46:47,552 workflow DEBUG:
# 	 /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/_0x6c428c57c0d0091e7c15bc3a045652fb_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 170823-15:46:47,558 workflow DEBUG:
# 	 Creating /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd
# 170823-15:46:47,583 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/_report/report.rst
# 170823-15:46:47,701 workflow DEBUG:
# 	 Executing node
# 170823-15:46:47,705 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 170823-15:46:47,713 interface DEBUG:
# 	 in_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Raw/002x-C-T1/pd.nii
# 170823-15:46:47,719 interface DEBUG:
# 	 out_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/pd_reoriented.nii
# 170823-15:46:47,736 workflow INFO:
# 	 Running: fslreorient2std /Volumes/iang/active/BABIES/BABIES_perfusion/Raw/002x-C-T1/pd.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/pd_reoriented.nii
# 170823-15:46:47,744 interface DEBUG:
# 	 in_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Raw/002x-C-T1/pd.nii
# 170823-15:46:47,750 interface DEBUG:
# 	 out_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/pd_reoriented.nii
# 170823-15:46:47,755 interface DEBUG:
# 	 {'DISPLAY': ':1'}
# 170823-15:46:47,791 workflow INFO:
# 	 [Job finished] jobname: reg2anat.a11 jobid: 18
# 170823-15:46:47,799 workflow INFO:
# 	 Executing: applyMask_pw.a11 ID: 19
# 170823-15:46:47,822 workflow INFO:
# 	 Executing node applyMask_pw.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/applyMask_pw
# 170823-15:46:47,942 workflow INFO:
# 	 Running: fslmaths /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reg2anat/pw_reoriented_flirt.nii -mas /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/binarize/processed_t2_out_reoriented_thresh.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/applyMask_pw/pw_reoriented_flirt_masked.nii
# 170823-15:46:48,917 workflow INFO:
# 	 [Job finished] jobname: applyMask_pw.a11 jobid: 19
# 170823-15:46:48,923 workflow INFO:
# 	 Executing: make_coreg_img.a11 ID: 20
# 170823-15:46:48,938 workflow DEBUG:
# 	 Needed files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/pd_reoriented.nii;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/pd_reoriented.mat;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/_0x6c428c57c0d0091e7c15bc3a045652fb_unfinished.json;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/command.txt;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/_inputs.pklz;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/_node.pklz170823-15:46:48,939 workflow INFO:
# 	 Executing node make_coreg_img.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_coreg_img
#
# 170823-15:46:48,948 workflow DEBUG:
# 	 Needed dirs: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/_report
# 170823-15:46:48,966 workflow DEBUG:
# 	 Removing files:
# 170823-15:46:48,987 workflow DEBUG:
# 	 saved results in /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/result_reorient_pd.pklz
# 170823-15:46:49,3 workflow DEBUG:
# 	 writing post-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/_report/report.rst
# 170823-15:46:49,15 workflow DEBUG:
# 	 Finished running reorient_pd.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd
#
# 170823-15:46:49,24 workflow INFO:
# 	 [Job finished] jobname: reorient_pd.a11 jobid: 22
# 170823-15:46:49,33 workflow INFO:
# 	 Executing: make_checkmask_img.a11 ID: 21
# 170823-15:46:49,53 workflow INFO:
# 	 Executing node make_checkmask_img.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_checkmask_img
# 170823-15:46:49,60 workflow DEBUG:
# 	 Found hashfiles: []
# 170823-15:46:49,63 workflow DEBUG:
# 	 Final hashfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_checkmask_img/_0x0a074c555cd0d24830d08fbd05faff73.json
# 170823-15:46:49,68 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 170823-15:46:49,74 workflow DEBUG:
# 	 Node hash: 0a074c555cd0d24830d08fbd05faff73
# 170823-15:46:49,86 workflow DEBUG:
# 	 /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_checkmask_img/_0x0a074c555cd0d24830d08fbd05faff73_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 170823-15:46:49,92 workflow DEBUG:
# 	 Creating /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_checkmask_img
# 170823-15:46:49,117 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_checkmask_img/_report/report.rst
# 170823-15:46:49,160 workflow DEBUG:
# 	 Executing node
# 170823-15:46:49,164 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 170823-15:46:50,489 workflow DEBUG:
# 	 Needed files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_checkmask_img/maskcheck.png;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_checkmask_img/_0x0a074c555cd0d24830d08fbd05faff73_unfinished.json;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_checkmask_img/_inputs.pklz;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_checkmask_img/_node.pklz
# 170823-15:46:50,499 workflow DEBUG:
# 	 Needed dirs: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_checkmask_img/_report
# 170823-15:46:50,514 workflow DEBUG:
# 	 Removing files:
# 170823-15:46:50,527 workflow DEBUG:
# 	 saved results in /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_checkmask_img/result_make_checkmask_img.pklz
# 170823-15:46:50,562 workflow DEBUG:
# 	 writing post-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_checkmask_img/_report/report.rst
# 170823-15:46:50,575 workflow DEBUG:
# 	 Finished running make_checkmask_img.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_checkmask_img
#
# 170823-15:46:50,580 workflow INFO:
# 	 [Job finished] jobname: make_checkmask_img.a11 jobid: 21
# 170823-15:46:50,590 workflow INFO:
# 	 Executing: applyxform.a11 ID: 23
# 170823-15:46:50,614 workflow INFO:
# 	 Executing node applyxform.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/applyxform
# 170823-15:46:50,622 workflow DEBUG:
# 	 Found hashfiles: []
# 170823-15:46:50,633 workflow DEBUG:
# 	 Final hashfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/applyxform/_0x73abfb3cc06deecf745a924aa94e1537.json
# 170823-15:46:50,639 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 170823-15:46:50,644 workflow DEBUG:
# 	 Node hash: 73abfb3cc06deecf745a924aa94e1537
# 170823-15:46:50,650 workflow DEBUG:
# 	 /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/applyxform/_0x73abfb3cc06deecf745a924aa94e1537_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 170823-15:46:50,656 workflow DEBUG:
# 	 Creating /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/applyxform
# 170823-15:46:50,680 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/applyxform/_report/report.rst
# 170823-15:46:50,738 workflow DEBUG:
# 	 Executing node
# 170823-15:46:50,746 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 170823-15:46:50,752 interface DEBUG:
# 	 apply_xfm_True
# 170823-15:46:50,756 interface DEBUG:
# 	 in_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/pd_reoriented.nii
# 170823-15:46:50,760 interface DEBUG:
# 	 in_matrix_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reg2anat/xform.mat
# 170823-15:46:50,771 interface DEBUG:
# 	 out_file_pd_reoriented_flirt.nii
# 170823-15:46:50,777 interface DEBUG:
# 	 out_matrix_file_pd_reoriented_flirt.mat
# 170823-15:46:50,783 interface DEBUG:
# 	 reference_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_anat/processed_t2_out_reoriented.nii
# 170823-15:46:50,795 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/pd_reoriented.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_anat/processed_t2_out_reoriented.nii -out pd_reoriented_flirt.nii -omat pd_reoriented_flirt.mat -applyxfm -init /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reg2anat/xform.mat
# 170823-15:46:50,802 interface DEBUG:
# 	 apply_xfm_True
# 170823-15:46:50,807 interface DEBUG:
# 	 in_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_pd/pd_reoriented.nii170823-15:46:50,806 workflow DEBUG:
# 	 Needed files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_coreg_img/coregistration.png;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_coreg_img/_0x2dd52b18753d7c933b8e77421ed9bd2d_unfinished.json;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_coreg_img/_inputs.pklz;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_coreg_img/_node.pklz
#
# 170823-15:46:50,813 interface DEBUG:
# 	 in_matrix_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reg2anat/xform.mat170823-15:46:50,813 workflow DEBUG:
# 	 Needed dirs: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_coreg_img/_report
#
# 170823-15:46:50,817 interface DEBUG:
# 	 out_file_pd_reoriented_flirt.nii
# 170823-15:46:50,820 interface DEBUG:
# 	 out_matrix_file_pd_reoriented_flirt.mat
# 170823-15:46:50,824 interface DEBUG:
# 	 reference_/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/reorient_anat/processed_t2_out_reoriented.nii
# 170823-15:46:50,827 workflow DEBUG:
# 	 Removing files: 170823-15:46:50,828 interface DEBUG:
# 	 {'DISPLAY': ':1'}
#
# 170823-15:46:50,842 workflow DEBUG:
# 	 saved results in /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_coreg_img/result_make_coreg_img.pklz
# 170823-15:46:50,858 workflow DEBUG:
# 	 writing post-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_coreg_img/_report/report.rst
# 170823-15:46:50,873 workflow DEBUG:
# 	 Finished running make_coreg_img.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_002x/make_coreg_img
#
# 170823-15:46:50,878 workflow INFO:
# 	 [Job finished] jobname: make_coreg_img.a11 jobid: 20
# 170823-15:46:50,887 workflow INFO:
# 	 Executing: selectfiles.a10 ID: 26
# 170823-15:46:50,892 workflow INFO:
# 	 Executing node selectfiles.a10 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/selectfiles
# 170823-15:46:50,896 workflow DEBUG:
# 	 Found hashfiles: []
# 170823-15:46:50,901 workflow DEBUG:
# 	 Final hashfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/selectfiles/_0x1bb4bf87ff74f4843a0b9d787418e72b.json
# 170823-15:46:50,905 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=True, hash_exists=False
# 170823-15:46:50,918 workflow DEBUG:
# 	 Node hash: 1bb4bf87ff74f4843a0b9d787418e72b
# 170823-15:46:50,922 workflow DEBUG:
# 	 /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/selectfiles/_0x1bb4bf87ff74f4843a0b9d787418e72b_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 170823-15:46:50,928 workflow DEBUG:
# 	 Creating /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/selectfiles
# 170823-15:46:50,961 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/selectfiles/_report/report.rst
# 170823-15:46:51,21 workflow DEBUG:
# 	 Executing node
# 170823-15:46:51,25 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 170823-15:46:51,69 workflow DEBUG:
# 	 Needed files: /Volumes/iang/active/BABIES/BABIES_perfusion/Raw/045-C-T1/processed_t2.nii;/Volumes/iang/active/BABIES/BABIES_perfusion/Raw/045-C-T1/processed_t2.mat;/Volumes/iang/active/BABIES/BABIES_perfusion/Raw/045-C-T1/pd.nii;/Volumes/iang/active/BABIES/BABIES_perfusion/Raw/045-C-T1/pd.mat;/Volumes/iang/active/BABIES/BABIES_perfusion/Raw/045-C-T1/pw.nii;/Volumes/iang/active/BABIES/BABIES_perfusion/Raw/045-C-T1/pw.mat;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/selectfiles/_0x1bb4bf87ff74f4843a0b9d787418e72b_unfinished.json;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/selectfiles/_inputs.pklz;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/selectfiles/_node.pklz
# 170823-15:46:51,72 workflow DEBUG:
# 	 Needed dirs: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/selectfiles/_report
# 170823-15:46:51,90 workflow DEBUG:
# 	 Removing files:
# 170823-15:46:51,104 workflow DEBUG:
# 	 saved results in /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/selectfiles/result_selectfiles.pklz
# 170823-15:46:51,120 workflow DEBUG:
# 	 writing post-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/selectfiles/_report/report.rst
# 170823-15:46:51,133 workflow DEBUG:
# 	 Finished running selectfiles.a10 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/selectfiles
#
# 170823-15:46:51,137 workflow INFO:
# 	 [Job finished] jobname: selectfiles.a10 jobid: 26
# 170823-15:46:51,145 workflow INFO:
# 	 Executing: mri_convert.a10 ID: 27
# 170823-15:46:51,160 workflow INFO:
# 	 Executing node mri_convert.a10 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/mri_convert
# 170823-15:46:51,166 workflow DEBUG:
# 	 Found hashfiles: []
# 170823-15:46:51,170 workflow DEBUG:
# 	 Final hashfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/mri_convert/_0xbf81e359c1a48b3fdb52200d6130b3da.json
# 170823-15:46:51,176 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 170823-15:46:51,181 workflow DEBUG:
# 	 Node hash: bf81e359c1a48b3fdb52200d6130b3da
# 170823-15:46:51,186 workflow DEBUG:
# 	 /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/mri_convert/_0xbf81e359c1a48b3fdb52200d6130b3da_unfinished.json found and can_resume is True or Node is a MapNode - resuming execution
# 170823-15:46:51,190 workflow DEBUG:
# 	 Creating /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/mri_convert
# 170823-15:46:51,217 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_045/mri_convert/_report/report.rst
# 170823-15:46:51,274 workflow DEBUG:
# 	 Executing node
# 170823-15:46:51,281 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 170823-15:46:51,288 interface DEBUG:
# 	 conform_size_2.0
# 170823-15:46:51,292 interface DEBUG:
# 	 crop_size_(128, 128, 128)
# 170823-15:46:51,296 interface DEBUG:
# 	 in_file_/Volumes/iang/active/BABIES/BABIES_perfusion/Raw/045-C-T1/processed_t2.nii
# 170823-15:46:51,301 interface DEBUG:
# ...
# 170823-15:51:40,583 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/_subjid_020/pd_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/020/pd_reoriented_flirt_masked.nii using '_subjid_' -> ''
# 170823-15:51:40,591 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/020/pd_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/020/pd_flirt_masked.nii using '_reoriented' -> ''
# 170823-15:51:40,595 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/_subjid_020/pd_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/020/pd_flirt_masked.nii
# 170823-15:51:40,620 interface DEBUG:
# 	 copyfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_020/applyMask_pd/pd_reoriented_flirt_masked.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/020/pd_flirt_masked.nii
# 170823-15:51:40,960 interface DEBUG:
# 	 key: masked_pw files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_020/applyMask_pw/pw_reoriented_flirt_masked.nii
# 170823-15:51:40,963 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/_subjid_020/pw_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/020/pw_reoriented_flirt_masked.nii using '_subjid_' -> ''
# 170823-15:51:40,967 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/020/pw_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/020/pw_flirt_masked.nii using '_reoriented' -> ''
# 170823-15:51:40,971 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/_subjid_020/pw_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/020/pw_flirt_masked.nii
# 170823-15:51:41,0 interface DEBUG:
# 	 copyfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_020/applyMask_pw/pw_reoriented_flirt_masked.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/020/pw_flirt_masked.nii
# 170823-15:51:41,390 interface DEBUG:
# 	 key: coreg_check files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_020/make_coreg_img/coregistration.png
# 170823-15:51:41,396 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/_subjid_020/coregistration.png -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/020/coregistration.png using '_subjid_' -> ''
# 170823-15:51:41,402 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/_subjid_020/coregistration.png -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/020/coregistration.png
# 170823-15:51:41,427 interface DEBUG:
# 	 copyfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_020/make_coreg_img/coregistration.png /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/020/coregistration.png
# 170823-15:51:41,472 interface DEBUG:
# 	 key: masked_check files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_020/make_checkmask_img/maskcheck.png
# 170823-15:51:41,476 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/_subjid_020/maskcheck.png -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/020/maskcheck.png using '_subjid_' -> ''
# 170823-15:51:41,480 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/_subjid_020/maskcheck.png -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/020/maskcheck.png
# 170823-15:51:41,489 interface DEBUG:
# 	 copyfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_020/make_checkmask_img/maskcheck.png /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/020/maskcheck.png
# 170823-15:51:41,570 workflow DEBUG:
# 	 Needed files: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/020/processed_t2_out.nii;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/020/processed_t2_out.mat;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/020/pd_flirt_masked.nii;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/020/pd_flirt_masked.mat;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/020/pw_flirt_masked.nii;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/020/pw_flirt_masked.mat;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/020/coregistration.png;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/020/maskcheck.png;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_020/datasink/_0x0968075079ce0b5d96d4eaa3802a7c0c_unfinished.json;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_020/datasink/_inputs.pklz;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_020/datasink/_node.pklz
# 170823-15:51:41,573 workflow DEBUG:
# 	 Needed dirs: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_020/datasink/_report
# 170823-15:51:41,591 workflow DEBUG:
# 	 Removing files:
# 170823-15:51:41,607 workflow DEBUG:
# 	 saved results in /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_020/datasink/result_datasink.pklz
# 170823-15:51:41,621 workflow DEBUG:
# 	 writing post-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_020/datasink/_report/report.rst
# 170823-15:51:41,635 workflow DEBUG:
# 	 Finished running datasink.a01 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_020/datasink
#
# 170823-15:51:41,639 workflow INFO:
# 	 [Job finished] jobname: datasink.a01 jobid: 155
# 170823-15:51:41,649 workflow INFO:
# 	 Executing: make_coreg_img.a00 ID: 163
# 170823-15:51:41,714 workflow INFO:
# 	 [Job finished] jobname: make_coreg_img.a00 jobid: 163
# 170823-15:51:41,717 workflow INFO:
# 	 Executing: make_checkmask_img.a00 ID: 164
# 170823-15:51:41,770 workflow INFO:
# 	 [Job finished] jobname: make_checkmask_img.a00 jobid: 164
# 170823-15:51:41,778 workflow INFO:
# 	 Executing: reorient_pd.a00 ID: 165
# 170823-15:51:41,797 workflow INFO:
# 	 [Job finished] jobname: reorient_pd.a00 jobid: 165
# 170823-15:51:41,807 workflow INFO:
# 	 Executing: applyxform.a00 ID: 166
# 170823-15:51:41,854 workflow INFO:
# 	 [Job finished] jobname: applyxform.a00 jobid: 166
# 170823-15:51:41,860 workflow INFO:
# 	 Executing: applyMask_pd.a00 ID: 167
# 170823-15:51:41,886 workflow INFO:
# 	 [Job finished] jobname: applyMask_pd.a00 jobid: 167
# 170823-15:51:41,892 workflow INFO:
# 	 Executing: datasink.a00 ID: 168
# 170823-15:51:42,2 workflow INFO:
# 	 Executing node datasink.a00 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/datasink
# 170823-15:51:42,12 workflow DEBUG:
# 	 Output dir: ['result_datasink.pklz', '_node.pklz', '_0x00b21b9bd07feb1987c350ae44e11af4.json', '_report', '_inputs.pklz']
# 170823-15:51:42,24 workflow DEBUG:
# 	 Output dir: ['result_datasink.pklz', '_node.pklz', '_0x00b21b9bd07feb1987c350ae44e11af4.json', '_report', '_inputs.pklz']
# 170823-15:51:42,36 workflow DEBUG:
# 	 Found hashfiles: ['/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/datasink/_0x00b21b9bd07feb1987c350ae44e11af4.json']
# 170823-15:51:42,39 workflow DEBUG:
# 	 Final hashfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/datasink/_0x00b21b9bd07feb1987c350ae44e11af4.json
# 170823-15:51:42,42 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=True, hash_exists=True
# 170823-15:51:42,46 workflow DEBUG:
# 	 Node hash: 00b21b9bd07feb1987c350ae44e11af4
# 170823-15:51:42,62 workflow DEBUG:
# 	 Rerunning node:
# updatehash = False, self.overwrite = None, self._interface.always_run = True, os.path.exists(/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/datasink/_0x00b21b9bd07feb1987c350ae44e11af4.json) = True, hash_method = timestamp
# 170823-15:51:42,89 workflow DEBUG:
# 	 Removing old /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/datasink and its contents
# 170823-15:51:42,321 workflow DEBUG:
# 	 Creating /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/datasink
# 170823-15:51:42,343 workflow DEBUG:
# 	 writing pre-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/datasink/_report/report.rst
# 170823-15:51:42,400 workflow DEBUG:
# 	 Executing node
# 170823-15:51:42,404 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 170823-15:51:42,409 interface DEBUG:
# 	 key: reorient_anat files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/reorient_anat/processed_t2_out_reoriented.nii
# 170823-15:51:42,413 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/_subjid_012/processed_t2_out_reoriented.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/012/processed_t2_out_reoriented.nii using '_subjid_' -> ''
# 170823-15:51:42,416 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/012/processed_t2_out_reoriented.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/012/processed_t2_out.nii using '_reoriented' -> ''
# 170823-15:51:42,419 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/_subjid_012/processed_t2_out_reoriented.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/012/processed_t2_out.nii
# 170823-15:51:42,423 interface DEBUG:
# 	 copyfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/reorient_anat/processed_t2_out_reoriented.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/012/processed_t2_out.nii
# 170823-15:51:42,674 interface DEBUG:
# 	 key: masked_pd files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/applyMask_pd/pd_reoriented_flirt_masked.nii
# 170823-15:51:42,678 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/_subjid_012/pd_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/012/pd_reoriented_flirt_masked.nii using '_subjid_' -> ''
# 170823-15:51:42,682 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/012/pd_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/012/pd_flirt_masked.nii using '_reoriented' -> ''
# 170823-15:51:42,686 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/_subjid_012/pd_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/012/pd_flirt_masked.nii
# 170823-15:51:42,689 interface DEBUG:
# 	 copyfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/applyMask_pd/pd_reoriented_flirt_masked.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/012/pd_flirt_masked.nii
# 170823-15:51:43,235 interface DEBUG:
# 	 key: masked_pw files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/applyMask_pw/pw_reoriented_flirt_masked.nii
# 170823-15:51:43,241 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/_subjid_012/pw_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/012/pw_reoriented_flirt_masked.nii using '_subjid_' -> ''
# 170823-15:51:43,245 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/012/pw_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/012/pw_flirt_masked.nii using '_reoriented' -> ''
# 170823-15:51:43,249 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/_subjid_012/pw_reoriented_flirt_masked.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/012/pw_flirt_masked.nii
# 170823-15:51:43,254 interface DEBUG:
# 	 copyfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/applyMask_pw/pw_reoriented_flirt_masked.nii /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/012/pw_flirt_masked.nii
# 170823-15:51:43,726 interface DEBUG:
# 	 key: coreg_check files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/make_coreg_img/coregistration.png
# 170823-15:51:43,732 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/_subjid_012/coregistration.png -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/012/coregistration.png using '_subjid_' -> ''
# 170823-15:51:43,737 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/_subjid_012/coregistration.png -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/012/coregistration.png
# 170823-15:51:43,740 interface DEBUG:
# 	 copyfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/make_coreg_img/coregistration.png /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/012/coregistration.png
# 170823-15:51:43,790 interface DEBUG:
# 	 key: masked_check files: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/make_checkmask_img/maskcheck.png
# 170823-15:51:43,794 interface DEBUG:
# 	 sub.str: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/_subjid_012/maskcheck.png -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/012/maskcheck.png using '_subjid_' -> ''
# 170823-15:51:43,799 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/_subjid_012/maskcheck.png -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/012/maskcheck.png
# 170823-15:51:43,805 interface DEBUG:
# 	 copyfile: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/make_checkmask_img/maskcheck.png /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/012/maskcheck.png
# 170823-15:51:43,868 workflow DEBUG:
# 	 Needed files: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/012/processed_t2_out.nii;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/012/processed_t2_out.mat;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/012/pd_flirt_masked.nii;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pd/012/pd_flirt_masked.mat;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/012/pw_flirt_masked.nii;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_pw/012/pw_flirt_masked.mat;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/coreg_check/012/coregistration.png;/Volumes/iang/active/BABIES/BABIES_perfusion/Proc/masked_check/012/maskcheck.png;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/datasink/_0x00b21b9bd07feb1987c350ae44e11af4_unfinished.json;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/datasink/_inputs.pklz;/Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/datasink/_node.pklz
# 170823-15:51:43,872 workflow DEBUG:
# 	 Needed dirs: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/datasink/_report
# 170823-15:51:43,890 workflow DEBUG:
# 	 Removing files:
# 170823-15:51:43,906 workflow DEBUG:
# 	 saved results in /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/datasink/result_datasink.pklz
# 170823-15:51:43,918 workflow DEBUG:
# 	 writing post-exec report to /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/datasink/_report/report.rst
# 170823-15:51:43,931 workflow DEBUG:
# 	 Finished running datasink.a00 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/preprocflow/_subjid_012/datasink
#
# 170823-15:51:43,942 workflow INFO:
# 	 [Job finished] jobname: datasink.a00 jobid: 168

# %%
## File handling nodes for CBF proc

# Select subjects
cbfinfosource = Node(IdentityInterface(fields=['subjid']),
                  name='cbfinfosource')
cbfinfosource.iterables = [('subjid', subjects_list)]


# SelectFiles
templates = {'pw_volume': output_dir + '/masked_pw/{subjid}/pw_flirt_masked.nii',
            'pd_volume': output_dir + '/masked_pd/{subjid}/pd_flirt_masked.nii',
            'anat_volume': output_dir + '/reorient_anat/{subjid}/processed_t2_out.nii'}
cbfselectfiles = Node(SelectFiles(templates), name='cbfselectfiles')

# Datasink
cbfdatasink = Node(DataSink(), name='cbfdatasink')
cbfdatasink.inputs.base_directory = output_dir
cbfdatasink.inputs.container = output_dir
# DataSink output substitutions (for ease of folder naming)
substitutions = [('_subjid_', '')]
cbfdatasink.inputs.substitutions = substitutions

# %%
## Custom functions

#quantify CBF from PW volume (Alsop MRIM 2015 method)
def quantify_cbf_alsop(pw_volume,pd_volume,sat_time,postlabel_delay,T1_blood,labeling_time,efficiency,partition_coeff,TR,T1_tissue,scaling_factor,nex_asl):
    import os
    import nibabel as nib
    from numpy import exp
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    # set variables
    pw_nifti1 = nib.load(pw_volume)
    pw_data = pw_nifti1.get_data()
    pw_data = pw_data.astype(float)
    pd_nifti1 = nib.load(pd_volume)
    pd_data = pd_nifti1.get_data()
    pd_data = pd_data.astype(float)
    conversion = 6000 #to convert values from mL/g/s to mL/100g/min
    pd_factor = 1/(1-exp((-1*TR)/T1_tissue))
    
    cbf_numerator = conversion*partition_coeff*pw_data*exp(postlabel_delay/T1_blood)
    cbf_denominator = sat_time*efficiency*T1_blood*scaling_factor*nex_asl*pd_data*pd_factor*(1-exp((-1*labeling_time)/T1_blood))
    cbf_data = cbf_numerator/cbf_denominator
    
    cbf_volume = nib.Nifti1Image(cbf_data, pw_nifti1.affine)
    nib.save(cbf_volume, 'alsop_cbf.nii')
    cbf_path = os.path.abspath('alsop_cbf.nii')
    return cbf_path

quant_cbf_alsop = Node(name='quant_cbf_alsop',
                interface=Function(input_names=['pw_volume','pd_volume',
                                                'sat_time','postlabel_delay',
                                                'T1_blood','labeling_time',
                                                'efficiency','partition_coeff',
                                                'TR','T1_tissue','scaling_factor',
                                                'nex_asl'],
                                  output_names=['cbf_volume'],
                                  function=quantify_cbf_alsop))
quant_cbf_alsop.inputs.sat_time=sat_time
quant_cbf_alsop.inputs.postlabel_delay=postlabel_delay
quant_cbf_alsop.inputs.T1_blood=T1_blood
quant_cbf_alsop.inputs.labeling_time=labeling_time
quant_cbf_alsop.inputs.efficiency=efficiency
quant_cbf_alsop.inputs.partition_coeff=partition_coeff
quant_cbf_alsop.inputs.TR=TR
quant_cbf_alsop.inputs.T1_tissue=T1_tissue
quant_cbf_alsop.inputs.scaling_factor=scaling_factor
quant_cbf_alsop.inputs.nex_asl=nex_asl

# %%
## Normalizing data for first and second level analysis

# Register subject's anatomy to the template
linearReg = Node(FLIRT(output_type='NIFTI',
                       reference=template),
                 name='linearReg')

## Register CBF vol to MNI space
# Volume Transformation - transform the cbf volume into MNI space
warpCBF = Node(ApplyVolTransform(inverse=False,
                                 target_file=template),
               name='warpCBF')

# Mask Gray Matter
#maskGrayMatter = Node(ApplyMask(mask_file=gray_matter_mask,
                                #output_type='NIFTI'),
                      #name='maskGrayMatter')

# %%
# create a flow for quantifying CBF and warping to MNI space.
cbfprocflow = Workflow(name='cbfprocflow')

# connect the nodes
cbfprocflow.connect([(cbfinfosource, cbfselectfiles, [('subjid', 'subjid')]),
                     (cbfselectfiles, quant_cbf_alsop, [('pw_volume', 'pw_volume')]),
                     (cbfselectfiles, quant_cbf_alsop, [('pd_volume', 'pd_volume')]),
                     (quant_cbf_alsop, cbfdatasink, [('cbf_volume', 'alsop_quant_cbf')]),
                     (cbfselectfiles, linearReg, [('anat_volume', 'in_file')]),
                     (linearReg, cbfdatasink, [('out_file','linwarped_anat')]),
                     (linearReg, warpCBF, [('out_matrix_file', 'fsl_reg_file')]),
                     (quant_cbf_alsop, warpCBF, [('cbf_volume', 'source_file')]),
                     (warpCBF, cbfdatasink, [('transformed_file', 'warped_cbf_vol')])
                     #(warpCBF, maskGrayMatter, [('transformed_file', 'in_file')]),
                     #(maskGrayMatter, cbfdatasink, [('out_file', 'masked_cbf')])
                    ]),
cbfprocflow.base_dir = opj(wkflow_dir)
cbfprocflow.write_graph(graph2use='flat')
cbfprocflow.run('MultiProc', plugin_args={'n_procs': 2})
# Out:
# 170823-16:03:40,569 workflow INFO:
# 	 Generated workflow graph: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/graph.dot.png (graph2use=flat, simple_form=True).
# 170823-16:03:40,608 workflow INFO:
# 	 Workflow cbfprocflow settings: ['check', 'execution', 'logging']
# 170823-16:03:40,777 workflow INFO:
# 	 Running in parallel.
# 170823-16:03:40,784 workflow INFO:
# 	 Executing: cbfselectfiles.a12 ID: 0
# 170823-16:03:40,819 workflow INFO:
# 	 Executing: cbfselectfiles.a11 ID: 5
# 170823-16:03:40,824 workflow INFO:
# 	 Executing node cbfselectfiles.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_033x/cbfselectfiles
# 170823-16:03:40,877 workflow INFO:
# 	 Executing node cbfselectfiles.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_002x/cbfselectfiles
# 170823-16:03:41,484 workflow INFO:
# 	 [Job finished] jobname: cbfselectfiles.a12 jobid: 0
# 170823-16:03:41,490 workflow INFO:
# 	 Executing: quant_cbf_alsop.a12 ID: 1
# 170823-16:03:41,521 workflow INFO:
# 	 [Job finished] jobname: quant_cbf_alsop.a12 jobid: 1
# 170823-16:03:41,523 workflow INFO:
# 	 [Job finished] jobname: cbfselectfiles.a11 jobid: 5
# 170823-16:03:41,530 workflow INFO:
# 	 Executing: linearReg.a12 ID: 2
# 170823-16:03:41,551 workflow INFO:
# 	 Executing: quant_cbf_alsop.a11 ID: 6
# 170823-16:03:41,554 workflow INFO:
# 	 Executing node linearReg.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_033x/linearReg
# 170823-16:03:41,596 workflow INFO:
# 	 [Job finished] jobname: quant_cbf_alsop.a11 jobid: 6
# 170823-16:03:41,796 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/033x/processed_t2_out.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii -out processed_t2_out_flirt.nii -omat processed_t2_out_flirt.mat
# 170823-16:03:43,607 workflow INFO:
# 	 Executing: linearReg.a11 ID: 7
# 170823-16:03:43,631 workflow INFO:
# 	 Executing node linearReg.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_002x/linearReg
# 170823-16:03:43,867 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/002x/processed_t2_out.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii -out processed_t2_out_flirt.nii -omat processed_t2_out_flirt.mat
# 170823-16:04:25,508 workflow INFO:
# 	 [Job finished] jobname: linearReg.a11 jobid: 7
# 170823-16:04:25,512 workflow INFO:
# 	 Executing: warpCBF.a11 ID: 8
# 170823-16:04:25,551 workflow INFO:
# 	 Executing node warpCBF.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_002x/warpCBF
# 170823-16:04:25,652 workflow INFO:
# 	 Running: mri_vol2vol --fsl /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_002x/linearReg/processed_t2_out_flirt.mat --mov /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_002x/warpCBF/alsop_cbf.nii --targ /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii --o /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_002x/warpCBF/alsop_cbf_warped.nii
# 170823-16:04:26,943 workflow INFO:
# 	 [Job finished] jobname: warpCBF.a11 jobid: 8
# 170823-16:04:26,948 workflow INFO:
# 	 Executing: cbfdatasink.a11 ID: 9
# 170823-16:04:26,971 workflow INFO:
# 	 Executing node cbfdatasink.a11 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_002x/cbfdatasink
# 170823-16:04:27,52 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/_subjid_002x/alsop_cbf.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/002x/alsop_cbf.nii
# 170823-16:04:27,666 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/_subjid_002x/alsop_cbf_warped.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/002x/alsop_cbf_warped.nii
# 170823-16:04:27,950 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/_subjid_002x/processed_t2_out_flirt.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/002x/processed_t2_out_flirt.nii
# 170823-16:04:28,145 workflow INFO:
# 	 [Job finished] jobname: cbfdatasink.a11 jobid: 9
# 170823-16:04:28,151 workflow INFO:
# 	 Executing: cbfselectfiles.a10 ID: 10
# 170823-16:04:28,181 workflow INFO:
# 	 Executing node cbfselectfiles.a10 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_045/cbfselectfiles
# 170823-16:04:28,673 workflow INFO:
# 	 [Job finished] jobname: cbfselectfiles.a10 jobid: 10
# 170823-16:04:28,680 workflow INFO:
# 	 Executing: quant_cbf_alsop.a10 ID: 11
# 170823-16:04:28,703 workflow INFO:
# 	 [Job finished] jobname: quant_cbf_alsop.a10 jobid: 11
# 170823-16:04:30,712 workflow INFO:
# 	 Executing: linearReg.a10 ID: 12
# 170823-16:04:30,749 workflow INFO:
# 	 Executing node linearReg.a10 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_045/linearReg
# 170823-16:04:31,61 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/045/processed_t2_out.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii -out processed_t2_out_flirt.nii -omat processed_t2_out_flirt.mat
# 170823-16:04:34,293 workflow INFO:
# 	 [Job finished] jobname: linearReg.a12 jobid: 2
# 170823-16:04:34,301 workflow INFO:
# 	 Executing: warpCBF.a12 ID: 3
# 170823-16:04:34,336 workflow INFO:
# 	 Executing node warpCBF.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_033x/warpCBF
# 170823-16:04:34,452 workflow INFO:
# 	 Running: mri_vol2vol --fsl /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_033x/linearReg/processed_t2_out_flirt.mat --mov /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_033x/warpCBF/alsop_cbf.nii --targ /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii --o /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_033x/warpCBF/alsop_cbf_warped.nii
# 170823-16:04:35,873 workflow INFO:
# 	 [Job finished] jobname: warpCBF.a12 jobid: 3
# 170823-16:04:35,878 workflow INFO:
# 	 Executing: cbfdatasink.a12 ID: 4
# 170823-16:04:35,902 workflow INFO:
# 	 Executing node cbfdatasink.a12 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_033x/cbfdatasink
# 170823-16:04:35,990 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/_subjid_033x/alsop_cbf.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/033x/alsop_cbf.nii
# 170823-16:04:36,630 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/_subjid_033x/alsop_cbf_warped.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/033x/alsop_cbf_warped.nii
# 170823-16:04:36,889 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/_subjid_033x/processed_t2_out_flirt.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/033x/processed_t2_out_flirt.nii
# 170823-16:04:37,68 workflow INFO:
# 	 [Job finished] jobname: cbfdatasink.a12 jobid: 4
# 170823-16:04:37,72 workflow INFO:
# 	 Executing: cbfselectfiles.a09 ID: 15
# 170823-16:04:37,92 workflow INFO:
# 	 Executing node cbfselectfiles.a09 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_039/cbfselectfiles
# 170823-16:04:37,520 workflow INFO:
# 	 [Job finished] jobname: cbfselectfiles.a09 jobid: 15
# 170823-16:04:37,526 workflow INFO:
# 	 Executing: quant_cbf_alsop.a09 ID: 16
# 170823-16:04:37,576 workflow INFO:
# 	 [Job finished] jobname: quant_cbf_alsop.a09 jobid: 16
# 170823-16:04:39,588 workflow INFO:
# 	 Executing: linearReg.a09 ID: 17
# 170823-16:04:39,613 workflow INFO:
# 	 Executing node linearReg.a09 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_039/linearReg
# 170823-16:04:39,938 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/039/processed_t2_out.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii -out processed_t2_out_flirt.nii -omat processed_t2_out_flirt.mat
# 170823-16:05:10,285 workflow INFO:
# 	 [Job finished] jobname: linearReg.a10 jobid: 12
# 170823-16:05:10,291 workflow INFO:
# 	 Executing: warpCBF.a10 ID: 13
# 170823-16:05:10,358 workflow INFO:
# 	 Executing node warpCBF.a10 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_045/warpCBF
# 170823-16:05:10,456 workflow INFO:
# 	 Running: mri_vol2vol --fsl /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_045/linearReg/processed_t2_out_flirt.mat --mov /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_045/warpCBF/alsop_cbf.nii --targ /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii --o /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_045/warpCBF/alsop_cbf_warped.nii
# 170823-16:05:12,413 workflow INFO:
# 	 [Job finished] jobname: warpCBF.a10 jobid: 13
# 170823-16:05:12,422 workflow INFO:
# 	 Executing: cbfdatasink.a10 ID: 14
# 170823-16:05:12,469 workflow INFO:
# 	 Executing node cbfdatasink.a10 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_045/cbfdatasink
# 170823-16:05:12,559 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/_subjid_045/alsop_cbf.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/045/alsop_cbf.nii
# 170823-16:05:13,169 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/_subjid_045/alsop_cbf_warped.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/045/alsop_cbf_warped.nii
# 170823-16:05:13,433 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/_subjid_045/processed_t2_out_flirt.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/045/processed_t2_out_flirt.nii
# 170823-16:05:13,826 workflow INFO:
# 	 [Job finished] jobname: cbfdatasink.a10 jobid: 14
# 170823-16:05:13,831 workflow INFO:
# 	 Executing: cbfselectfiles.a08 ID: 20
# 170823-16:05:13,888 workflow INFO:
# 	 Executing node cbfselectfiles.a08 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_036/cbfselectfiles
# 170823-16:05:14,206 workflow INFO:
# 	 [Job finished] jobname: cbfselectfiles.a08 jobid: 20
# 170823-16:05:14,212 workflow INFO:
# 	 Executing: quant_cbf_alsop.a08 ID: 21
# 170823-16:05:14,261 workflow INFO:
# 	 [Job finished] jobname: quant_cbf_alsop.a08 jobid: 21
# 170823-16:05:16,271 workflow INFO:
# 	 Executing: linearReg.a08 ID: 22
# 170823-16:05:16,329 workflow INFO:
# 	 Executing node linearReg.a08 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_036/linearReg
# 170823-16:05:16,610 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/036/processed_t2_out.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii -out processed_t2_out_flirt.nii -omat processed_t2_out_flirt.mat
# 170823-16:05:17,869 workflow INFO:
# 	 [Job finished] jobname: linearReg.a09 jobid: 17
# 170823-16:05:17,874 workflow INFO:
# 	 Executing: warpCBF.a09 ID: 18
# 170823-16:05:17,893 workflow INFO:
# 	 Executing node warpCBF.a09 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_039/warpCBF
# 170823-16:05:17,993 workflow INFO:
# 	 Running: mri_vol2vol --fsl /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_039/linearReg/processed_t2_out_flirt.mat --mov /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_039/warpCBF/alsop_cbf.nii --targ /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii --o /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_039/warpCBF/alsop_cbf_warped.nii
# 170823-16:05:19,293 workflow INFO:
# 	 [Job finished] jobname: warpCBF.a09 jobid: 18
# 170823-16:05:19,298 workflow INFO:
# 	 Executing: cbfdatasink.a09 ID: 19
# 170823-16:05:19,320 workflow INFO:
# 	 Executing node cbfdatasink.a09 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_039/cbfdatasink
# 170823-16:05:19,407 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/_subjid_039/alsop_cbf.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/039/alsop_cbf.nii
# 170823-16:05:20,32 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/_subjid_039/alsop_cbf_warped.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/039/alsop_cbf_warped.nii
# 170823-16:05:20,330 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/_subjid_039/processed_t2_out_flirt.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/039/processed_t2_out_flirt.nii
# 170823-16:05:20,620 workflow INFO:
# 	 [Job finished] jobname: cbfdatasink.a09 jobid: 19
# 170823-16:05:20,624 workflow INFO:
# 	 Executing: cbfselectfiles.a07 ID: 25
# 170823-16:05:20,643 workflow INFO:
# 	 Executing node cbfselectfiles.a07 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_035/cbfselectfiles
# 170823-16:05:21,3 workflow INFO:
# 	 [Job finished] jobname: cbfselectfiles.a07 jobid: 25
# 170823-16:05:21,8 workflow INFO:
# 	 Executing: quant_cbf_alsop.a07 ID: 26
# 170823-16:05:21,63 workflow INFO:
# 	 [Job finished] jobname: quant_cbf_alsop.a07 jobid: 26
# 170823-16:05:23,70 workflow INFO:
# 	 Executing: linearReg.a07 ID: 27
# 170823-16:05:23,91 workflow INFO:
# 	 Executing node linearReg.a07 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_035/linearReg
# 170823-16:05:23,343 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/035/processed_t2_out.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii -out processed_t2_out_flirt.nii -omat processed_t2_out_flirt.mat
# 170823-16:05:55,987 workflow INFO:
# 	 [Job finished] jobname: linearReg.a08 jobid: 22
# 170823-16:05:55,992 workflow INFO:
# 	 Executing: warpCBF.a08 ID: 23
# 170823-16:05:56,29 workflow INFO:
# 	 Executing node warpCBF.a08 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_036/warpCBF
# 170823-16:05:56,127 workflow INFO:
# 	 Running: mri_vol2vol --fsl /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_036/linearReg/processed_t2_out_flirt.mat --mov /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_036/warpCBF/alsop_cbf.nii --targ /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii --o /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_036/warpCBF/alsop_cbf_warped.nii
# 170823-16:05:57,841 workflow INFO:
# 	 [Job finished] jobname: warpCBF.a08 jobid: 23
# 170823-16:05:57,845 workflow INFO:
# 	 Executing: cbfdatasink.a08 ID: 24
# 170823-16:05:57,869 workflow INFO:
# 	 Executing node cbfdatasink.a08 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_036/cbfdatasink
# 170823-16:05:57,941 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/_subjid_036/alsop_cbf.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/036/alsop_cbf.nii
# 170823-16:05:58,515 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/_subjid_036/alsop_cbf_warped.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/036/alsop_cbf_warped.nii
# 170823-16:05:58,771 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/_subjid_036/processed_t2_out_flirt.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/036/processed_t2_out_flirt.nii
# 170823-16:05:58,979 workflow INFO:
# 	 [Job finished] jobname: cbfdatasink.a08 jobid: 24
# 170823-16:05:58,982 workflow INFO:
# 	 Executing: cbfselectfiles.a06 ID: 30
# 170823-16:05:59,13 workflow INFO:
# 	 Executing node cbfselectfiles.a06 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_032/cbfselectfiles
# 170823-16:05:59,449 workflow INFO:
# 	 [Job finished] jobname: cbfselectfiles.a06 jobid: 30
# 170823-16:05:59,453 workflow INFO:
# 	 Executing: quant_cbf_alsop.a06 ID: 31
# 170823-16:05:59,506 workflow INFO:
# 	 [Job finished] jobname: quant_cbf_alsop.a06 jobid: 31
# 170823-16:06:01,514 workflow INFO:
# 	 Executing: linearReg.a06 ID: 32
# 170823-16:06:01,583 workflow INFO:
# 	 Executing node linearReg.a06 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_032/linearReg
# 170823-16:06:01,913 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/032/processed_t2_out.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii -out processed_t2_out_flirt.nii -omat processed_t2_out_flirt.mat
# 170823-16:06:06,363 workflow INFO:
# 	 [Job finished] jobname: linearReg.a07 jobid: 27
# 170823-16:06:06,368 workflow INFO:
# 	 Executing: warpCBF.a07 ID: 28
# 170823-16:06:06,400 workflow INFO:
# 	 Executing node warpCBF.a07 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_035/warpCBF
# 170823-16:06:06,501 workflow INFO:
# 	 Running: mri_vol2vol --fsl /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_035/linearReg/processed_t2_out_flirt.mat --mov /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_035/warpCBF/alsop_cbf.nii --targ /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii --o /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_035/warpCBF/alsop_cbf_warped.nii
# 170823-16:06:07,715 workflow INFO:
# 	 [Job finished] jobname: warpCBF.a07 jobid: 28
# 170823-16:06:07,721 workflow INFO:
# 	 Executing: cbfdatasink.a07 ID: 29
# 170823-16:06:07,839 workflow INFO:
# 	 Executing node cbfdatasink.a07 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_035/cbfdatasink
# 170823-16:06:07,923 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/_subjid_035/alsop_cbf.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/035/alsop_cbf.nii
# 170823-16:06:08,465 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/_subjid_035/alsop_cbf_warped.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/035/alsop_cbf_warped.nii
# 170823-16:06:08,725 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/_subjid_035/processed_t2_out_flirt.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/035/processed_t2_out_flirt.nii
# 170823-16:06:08,960 workflow INFO:
# 	 [Job finished] jobname: cbfdatasink.a07 jobid: 29
# 170823-16:06:08,964 workflow INFO:
# 	 Executing: cbfselectfiles.a05 ID: 35
# 170823-16:06:08,998 workflow INFO:
# 	 Executing node cbfselectfiles.a05 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_031/cbfselectfiles
# 170823-16:06:09,387 workflow INFO:
# 	 [Job finished] jobname: cbfselectfiles.a05 jobid: 35
# 170823-16:06:09,392 workflow INFO:
# 	 Executing: quant_cbf_alsop.a05 ID: 36
# 170823-16:06:09,457 workflow INFO:
# 	 [Job finished] jobname: quant_cbf_alsop.a05 jobid: 36
# 170823-16:06:11,467 workflow INFO:
# 	 Executing: linearReg.a05 ID: 37
# 170823-16:06:11,506 workflow INFO:
# 	 Executing node linearReg.a05 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_031/linearReg
# 170823-16:06:11,745 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/031/processed_t2_out.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii -out processed_t2_out_flirt.nii -omat processed_t2_out_flirt.mat
# 170823-16:06:46,635 workflow INFO:
# 	 [Job finished] jobname: linearReg.a06 jobid: 32
# 170823-16:06:46,641 workflow INFO:
# 	 Executing: warpCBF.a06 ID: 33
# 170823-16:06:46,677 workflow INFO:
# 	 Executing node warpCBF.a06 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_032/warpCBF
# 170823-16:06:46,775 workflow INFO:
# 	 Running: mri_vol2vol --fsl /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_032/linearReg/processed_t2_out_flirt.mat --mov /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_032/warpCBF/alsop_cbf.nii --targ /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii --o /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_032/warpCBF/alsop_cbf_warped.nii
# 170823-16:06:48,147 workflow INFO:
# 	 [Job finished] jobname: warpCBF.a06 jobid: 33
# 170823-16:06:48,154 workflow INFO:
# 	 Executing: cbfdatasink.a06 ID: 34
# 170823-16:06:48,177 workflow INFO:
# 	 Executing node cbfdatasink.a06 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_032/cbfdatasink
# 170823-16:06:48,258 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/_subjid_032/alsop_cbf.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/032/alsop_cbf.nii
# 170823-16:06:48,894 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/_subjid_032/alsop_cbf_warped.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/032/alsop_cbf_warped.nii
# 170823-16:06:49,140 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/_subjid_032/processed_t2_out_flirt.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/032/processed_t2_out_flirt.nii
# 170823-16:06:49,391 workflow INFO:
# 	 [Job finished] jobname: cbfdatasink.a06 jobid: 34
# 170823-16:06:49,396 workflow INFO:
# 	 Executing: cbfselectfiles.a04 ID: 40
# 170823-16:06:49,431 workflow INFO:
# 	 Executing node cbfselectfiles.a04 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_027/cbfselectfiles
# 170823-16:06:49,810 workflow INFO:
# 	 [Job finished] jobname: cbfselectfiles.a04 jobid: 40
# 170823-16:06:49,814 workflow INFO:
# 	 Executing: quant_cbf_alsop.a04 ID: 41
# 170823-16:06:49,855 workflow INFO:
# 	 [Job finished] jobname: quant_cbf_alsop.a04 jobid: 41
# 170823-16:06:51,867 workflow INFO:
# 	 Executing: linearReg.a04 ID: 42
# 170823-16:06:51,888 workflow INFO:
# 	 Executing node linearReg.a04 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_027/linearReg
# 170823-16:06:52,228 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/027/processed_t2_out.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii -out processed_t2_out_flirt.nii -omat processed_t2_out_flirt.mat
# 170823-16:06:52,852 workflow INFO:
# 	 [Job finished] jobname: linearReg.a05 jobid: 37
# 170823-16:06:52,856 workflow INFO:
# 	 Executing: warpCBF.a05 ID: 38
# 170823-16:06:52,880 workflow INFO:
# 	 Executing node warpCBF.a05 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_031/warpCBF
# 170823-16:06:52,978 workflow INFO:
# 	 Running: mri_vol2vol --fsl /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_031/linearReg/processed_t2_out_flirt.mat --mov /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_031/warpCBF/alsop_cbf.nii --targ /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii --o /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_031/warpCBF/alsop_cbf_warped.nii
# 170823-16:06:54,166 workflow INFO:
# 	 [Job finished] jobname: warpCBF.a05 jobid: 38
# 170823-16:06:54,170 workflow INFO:
# 	 Executing: cbfdatasink.a05 ID: 39
# 170823-16:06:54,193 workflow INFO:
# 	 Executing node cbfdatasink.a05 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_031/cbfdatasink
# 170823-16:06:54,271 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/_subjid_031/alsop_cbf.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/031/alsop_cbf.nii
# 170823-16:06:54,831 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/_subjid_031/alsop_cbf_warped.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/031/alsop_cbf_warped.nii
# 170823-16:06:55,60 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/_subjid_031/processed_t2_out_flirt.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/031/processed_t2_out_flirt.nii
# 170823-16:06:55,302 workflow INFO:
# 	 [Job finished] jobname: cbfdatasink.a05 jobid: 39
# 170823-16:06:55,306 workflow INFO:
# 	 Executing: cbfselectfiles.a03 ID: 45
# 170823-16:06:55,340 workflow INFO:
# 	 Executing node cbfselectfiles.a03 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_023/cbfselectfiles
# 170823-16:06:55,623 workflow INFO:
# 	 [Job finished] jobname: cbfselectfiles.a03 jobid: 45
# 170823-16:06:55,629 workflow INFO:
# 	 Executing: quant_cbf_alsop.a03 ID: 46
# 170823-16:06:55,674 workflow INFO:
# 	 [Job finished] jobname: quant_cbf_alsop.a03 jobid: 46
# 170823-16:06:57,684 workflow INFO:
# 	 Executing: linearReg.a03 ID: 47
# 170823-16:06:57,707 workflow INFO:
# 	 Executing node linearReg.a03 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_023/linearReg
# 170823-16:06:57,934 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/023/processed_t2_out.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii -out processed_t2_out_flirt.nii -omat processed_t2_out_flirt.mat
# 170823-16:07:34,429 workflow INFO:
# 	 [Job finished] jobname: linearReg.a04 jobid: 42
# 170823-16:07:34,435 workflow INFO:
# 	 Executing: warpCBF.a04 ID: 43
# 170823-16:07:34,469 workflow INFO:
# 	 Executing node warpCBF.a04 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_027/warpCBF
# 170823-16:07:34,573 workflow INFO:
# 	 Running: mri_vol2vol --fsl /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_027/linearReg/processed_t2_out_flirt.mat --mov /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_027/warpCBF/alsop_cbf.nii --targ /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii --o /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_027/warpCBF/alsop_cbf_warped.nii
# 170823-16:07:35,742 workflow INFO:
# 	 [Job finished] jobname: warpCBF.a04 jobid: 43
# 170823-16:07:35,749 workflow INFO:
# 	 Executing: cbfdatasink.a04 ID: 44
# 170823-16:07:35,795 workflow INFO:
# 	 Executing node cbfdatasink.a04 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_027/cbfdatasink
# 170823-16:07:35,883 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/_subjid_027/alsop_cbf.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/027/alsop_cbf.nii
# 170823-16:07:37,224 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/_subjid_027/alsop_cbf_warped.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/027/alsop_cbf_warped.nii
# 170823-16:07:37,490 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/_subjid_027/processed_t2_out_flirt.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/027/processed_t2_out_flirt.nii
# 170823-16:07:37,680 workflow INFO:
# 	 [Job finished] jobname: cbfdatasink.a04 jobid: 44
# 170823-16:07:37,689 workflow INFO:
# 	 Executing: cbfselectfiles.a02 ID: 50
# 170823-16:07:37,742 workflow INFO:
# 	 Executing node cbfselectfiles.a02 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_021/cbfselectfiles
# 170823-16:07:38,210 workflow INFO:
# 	 [Job finished] jobname: cbfselectfiles.a02 jobid: 50
# 170823-16:07:38,215 workflow INFO:
# 	 Executing: quant_cbf_alsop.a02 ID: 51
# 170823-16:07:38,283 workflow INFO:
# 	 [Job finished] jobname: quant_cbf_alsop.a02 jobid: 51
# 170823-16:07:40,291 workflow INFO:
# 	 Executing: linearReg.a02 ID: 52
# 170823-16:07:40,358 workflow INFO:
# 	 Executing node linearReg.a02 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_021/linearReg
# 170823-16:07:40,719 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/021/processed_t2_out.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii -out processed_t2_out_flirt.nii -omat processed_t2_out_flirt.mat
# 170823-16:07:42,819 workflow INFO:
# 	 [Job finished] jobname: linearReg.a03 jobid: 47
# 170823-16:07:42,825 workflow INFO:
# 	 Executing: warpCBF.a03 ID: 48
# 170823-16:07:42,854 workflow INFO:
# 	 Executing node warpCBF.a03 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_023/warpCBF
# 170823-16:07:42,949 workflow INFO:
# 	 Running: mri_vol2vol --fsl /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_023/linearReg/processed_t2_out_flirt.mat --mov /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_023/warpCBF/alsop_cbf.nii --targ /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii --o /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_023/warpCBF/alsop_cbf_warped.nii
# 170823-16:07:44,110 workflow INFO:
# 	 [Job finished] jobname: warpCBF.a03 jobid: 48
# 170823-16:07:44,114 workflow INFO:
# 	 Executing: cbfdatasink.a03 ID: 49
# 170823-16:07:44,138 workflow INFO:
# 	 Executing node cbfdatasink.a03 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_023/cbfdatasink
# 170823-16:07:44,218 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/_subjid_023/alsop_cbf.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/023/alsop_cbf.nii
# 170823-16:07:44,879 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/_subjid_023/alsop_cbf_warped.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/023/alsop_cbf_warped.nii
# 170823-16:07:45,152 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/_subjid_023/processed_t2_out_flirt.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/023/processed_t2_out_flirt.nii
# 170823-16:07:45,352 workflow INFO:
# 	 [Job finished] jobname: cbfdatasink.a03 jobid: 49
# 170823-16:07:45,358 workflow INFO:
# 	 Executing: cbfselectfiles.a01 ID: 55
# 170823-16:07:45,376 workflow INFO:
# 	 Executing node cbfselectfiles.a01 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_020/cbfselectfiles
# 170823-16:07:45,800 workflow INFO:
# 	 [Job finished] jobname: cbfselectfiles.a01 jobid: 55
# 170823-16:07:45,805 workflow INFO:
# 	 Executing: quant_cbf_alsop.a01 ID: 56
# 170823-16:07:45,851 workflow INFO:
# 	 [Job finished] jobname: quant_cbf_alsop.a01 jobid: 56
# 170823-16:07:47,861 workflow INFO:
# 	 Executing: linearReg.a01 ID: 57
# 170823-16:07:47,907 workflow INFO:
# 	 Executing node linearReg.a01 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_020/linearReg
# 170823-16:07:48,262 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/020/processed_t2_out.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii -out processed_t2_out_flirt.nii -omat processed_t2_out_flirt.mat
# 170823-16:08:24,424 workflow INFO:
# 	 [Job finished] jobname: linearReg.a02 jobid: 52
# 170823-16:08:24,428 workflow INFO:
# 	 Executing: warpCBF.a02 ID: 53
# 170823-16:08:24,458 workflow INFO:
# 	 Executing node warpCBF.a02 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_021/warpCBF
# 170823-16:08:24,765 workflow INFO:
# 	 Running: mri_vol2vol --fsl /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_021/linearReg/processed_t2_out_flirt.mat --mov /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_021/warpCBF/alsop_cbf.nii --targ /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii --o /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_021/warpCBF/alsop_cbf_warped.nii
# 170823-16:08:26,17 workflow INFO:
# 	 [Job finished] jobname: warpCBF.a02 jobid: 53
# 170823-16:08:26,22 workflow INFO:
# 	 Executing: cbfdatasink.a02 ID: 54
# 170823-16:08:26,46 workflow INFO:
# 	 Executing node cbfdatasink.a02 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_021/cbfdatasink
# 170823-16:08:26,127 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/_subjid_021/alsop_cbf.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/021/alsop_cbf.nii
# 170823-16:08:26,730 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/_subjid_021/alsop_cbf_warped.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/021/alsop_cbf_warped.nii
# 170823-16:08:27,13 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/_subjid_021/processed_t2_out_flirt.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/021/processed_t2_out_flirt.nii
# 170823-16:08:27,198 workflow INFO:
# 	 [Job finished] jobname: cbfdatasink.a02 jobid: 54
# 170823-16:08:27,202 workflow INFO:
# 	 Executing: cbfselectfiles.a00 ID: 60
# 170823-16:08:27,300 workflow INFO:
# 	 Executing node cbfselectfiles.a00 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_012/cbfselectfiles
# 170823-16:08:27,735 workflow INFO:
# 	 [Job finished] jobname: cbfselectfiles.a00 jobid: 60
# 170823-16:08:27,741 workflow INFO:
# 	 Executing: quant_cbf_alsop.a00 ID: 61
# 170823-16:08:27,799 workflow INFO:
# 	 [Job finished] jobname: quant_cbf_alsop.a00 jobid: 61
# 170823-16:08:29,805 workflow INFO:
# 	 Executing: linearReg.a00 ID: 62
# 170823-16:08:29,863 workflow INFO:
# 	 Executing node linearReg.a00 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_012/linearReg
# 170823-16:08:30,119 workflow INFO:
# 	 Running: flirt -in /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/reorient_anat/012/processed_t2_out.nii -ref /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii -out processed_t2_out_flirt.nii -omat processed_t2_out_flirt.mat
# 170823-16:08:32,340 workflow INFO:
# 	 [Job finished] jobname: linearReg.a01 jobid: 57
# 170823-16:08:32,344 workflow INFO:
# 	 Executing: warpCBF.a01 ID: 58
# 170823-16:08:32,394 workflow INFO:
# 	 Executing node warpCBF.a01 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_020/warpCBF
# 170823-16:08:32,486 workflow INFO:
# 	 Running: mri_vol2vol --fsl /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_020/linearReg/processed_t2_out_flirt.mat --mov /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_020/warpCBF/alsop_cbf.nii --targ /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii --o /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_020/warpCBF/alsop_cbf_warped.nii
# 170823-16:08:34,129 workflow INFO:
# 	 [Job finished] jobname: warpCBF.a01 jobid: 58
# 170823-16:08:34,133 workflow INFO:
# 	 Executing: cbfdatasink.a01 ID: 59
# 170823-16:08:34,159 workflow INFO:
# 	 Executing node cbfdatasink.a01 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_020/cbfdatasink
# 170823-16:08:34,242 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/_subjid_020/alsop_cbf.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/020/alsop_cbf.nii
# 170823-16:08:34,853 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/_subjid_020/alsop_cbf_warped.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/020/alsop_cbf_warped.nii
# 170823-16:08:35,111 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/_subjid_020/processed_t2_out_flirt.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/020/processed_t2_out_flirt.nii
# 170823-16:08:35,315 workflow INFO:
# 	 [Job finished] jobname: cbfdatasink.a01 jobid: 59
# 170823-16:09:05,698 workflow INFO:
# 	 [Job finished] jobname: linearReg.a00 jobid: 62
# 170823-16:09:05,702 workflow INFO:
# 	 Executing: warpCBF.a00 ID: 63
# 170823-16:09:05,731 workflow INFO:
# 	 Executing node warpCBF.a00 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_012/warpCBF
# 170823-16:09:05,834 workflow INFO:
# 	 Running: mri_vol2vol --fsl /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_012/linearReg/processed_t2_out_flirt.mat --mov /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_012/warpCBF/alsop_cbf.nii --targ /Volumes/iang/active/BABIES/BABIES_perfusion/Templates/T2wtemplate_2mm.nii --o /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_012/warpCBF/alsop_cbf_warped.nii
# 170823-16:09:07,280 workflow INFO:
# 	 [Job finished] jobname: warpCBF.a00 jobid: 63
# 170823-16:09:07,284 workflow INFO:
# 	 Executing: cbfdatasink.a00 ID: 64
# 170823-16:09:07,312 workflow INFO:
# 	 Executing node cbfdatasink.a00 in dir: /Volumes/iang/active/BABIES/BABIES_perfusion/Workflows/cbfprocflow/_subjid_012/cbfdatasink
# 170823-16:09:07,392 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/_subjid_012/alsop_cbf.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/alsop_quant_cbf/012/alsop_cbf.nii
# 170823-16:09:08,79 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/_subjid_012/alsop_cbf_warped.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/warped_cbf_vol/012/alsop_cbf_warped.nii
# 170823-16:09:08,353 interface INFO:
# 	 sub: /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/_subjid_012/processed_t2_out_flirt.nii -> /Volumes/iang/active/BABIES/BABIES_perfusion/Proc/linwarped_anat/012/processed_t2_out_flirt.nii
# 170823-16:09:08,542 workflow INFO:
# 	 [Job finished] jobname: cbfdatasink.a00 jobid: 64
